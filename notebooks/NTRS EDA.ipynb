# %%
import pandas as pd

# %%
import pandas as pd

# List of CSV files to read
csv_files = ['../data/ntrs-2021.csv', '../data/ntrs-2022.csv', '../data/ntrs-2023.csv']

# Read and concatenate the CSV files
dfs = [pd.read_csv(file, index_col = 0) for file in csv_files]
combined_df = pd.concat(dfs, ignore_index=True).drop('Lastmod', axis = 1)

# Display the combined DataFrame
combined_df.dropna(inplace = True)

# %%
combined_df
# Out:
#                                               URL  \
# 0     https://ntrs.nasa.gov/citations/20205001069
# 1     https://ntrs.nasa.gov/citations/20205001711
# 2     https://ntrs.nasa.gov/citations/20205002597
# 3     https://ntrs.nasa.gov/citations/20205002632
# 4     https://ntrs.nasa.gov/citations/20205003825
# ...                                           ...
# 6356  https://ntrs.nasa.gov/citations/20220015029
# 6357  https://ntrs.nasa.gov/citations/20220015095
# 6359  https://ntrs.nasa.gov/citations/20220015734
# 6360  https://ntrs.nasa.gov/citations/20220015753
# 6361  https://ntrs.nasa.gov/citations/20220015900
#
#                                                   Title  \
# 0     Volatile chemical product emissions enhance oz...
# 1     Phase Diagram, Melt Growth and Characterizatio...
# 2     Assessment and Improvement of RANS-based Trans...
# 3     A Computational Analysis of Boundary Layer Ins...
# 4     Non-Monotonic Response of the Climate System t...
# ...                                                 ...
# 6356  Galvanic Vestibular Reduction Modifies Percept...
# 6357  The Effects of Space Flight and Microgravity E...
# 6359  Runtime Assurance of Aeronautical Products: Pr...
# 6360  NASA Advanced Space Suit Pressure Garment Syst...
# 6361  Application of Acoustical Holography for Proje...
#
#                                             Description
# 0     Decades of air quality improvements have subst...
# 1     In this study, the solidus curve of the Cd0.8Z...
# 2     Transition models based on auxiliary transport...
# 3     The complex boundary layer flow over the BOLT ...
# 4     We explore the climate system response to abru...
# ...                                                 ...
# 6356  INTRODUCTION: Alterations in vestibular sensor...
# 6357  Over the past half century, our understanding ...
# 6359  Runtime assurance (RTA) affords an operational...
# 6360  This paper discusses the current focus of NASA...
# 6361  In this report, the application of the acousti...
#
# [5683 rows x 3 columns]
