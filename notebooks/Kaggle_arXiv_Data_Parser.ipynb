# %% [markdown]
# # Kaggle arXiv Data Parser
#
# [Source](https://www.kaggle.com/code/kaggleaccount2112/extract-explainable-aiml-articles-from-arxiv-data)

# %%
import os

import pandas as pd
import json
from collections import defaultdict

# Paste your username where is says 'username'
# and your API key where it say 'key'

os.environ['KAGGLE_USERNAME'] = 'nickmccarty'
os.environ['KAGGLE_KEY'] = ''

# Install Kaggle packages

# !pip install -q kaggle

# Download the data set

# !kaggle datasets download -d Cornell-University/arxiv

# Remove the sample_data folder from our working directory

# !rm -r sample_data

# If you get any errors, its likely due to conflicts in the Python versions and the Unix versions,
# but they should not be an issue. They are more warnings, then errors.
# As long as it downloads the data, you're fine.

# !unzip arxiv.zip
# !rm -r arxiv.zip
# Out:
# Downloading arxiv.zip to /content
# 100% 1.17G/1.18G [00:16<00:00, 126MB/s]
# 100% 1.18G/1.18G [00:16<00:00, 78.4MB/s]

# %%
# 'xai' is kept as a single term keyword
single_term_keywords = ['xai']

descriptors = ['explainable', 'transparent', 'interpretable']
terms = ['ai', 'machine learning', 'aiml']

keywords = [f'{descriptor} {term}' for descriptor in descriptors for term in terms]
keywords.extend(single_term_keywords)

descriptors_anti = ['black-box', 'black box', 'opaque', 'uninterpretable', 'non-transparent', 'inexplicable', 'unexplainable']
anti_keywords = [f'{descriptor} {term}' for descriptor in descriptors_anti for term in terms]

print(f'Keywords: {", ".join(keywords)}')
print(f'Anti-Keywords: {", ".join(anti_keywords)}')
# Out:
# Keywords: explainable ai, explainable machine learning, explainable aiml, transparent ai, transparent machine learning, transparent aiml, interpretable ai, interpretable machine learning, interpretable aiml, xai
# Anti-Keywords: black-box ai, black-box machine learning, black-box aiml, black box ai, black box machine learning, black box aiml, opaque ai, opaque machine learning, opaque aiml, uninterpretable ai, uninterpretable machine learning, uninterpretable aiml, non-transparent ai, non-transparent machine learning, non-transparent aiml, inexplicable ai, inexplicable machine learning, inexplicable aiml, unexplainable ai, unexplainable machine learning, unexplainable aiml

# %%
# Create a dictionary to keep count of articles for each keyword
keyword_counts = defaultdict(int)
anti_keyword_counts = defaultdict(int)

# List to store articles
articles = []

with open('arxiv-metadata-oai-snapshot.json', 'r') as f:
    for i, line in enumerate(f):
        article = json.loads(line)
        title = article.get('title', '').lower()
        abstract = article.get('abstract', '').lower()

        # keep a list of keywords that match for this article
        matching_keywords = [keyword for keyword in keywords if keyword in abstract or keyword in title]
        matching_anti_keywords = [keyword for keyword in anti_keywords if keyword in abstract or keyword in title]

        # increment count for each keyword found in the title or abstract
        for keyword in matching_keywords:
            keyword_counts[keyword] += 1

        for keyword in matching_anti_keywords:
            anti_keyword_counts[keyword] += 1

        if matching_keywords or matching_anti_keywords:
            # append the matching keywords to the article data
            article['matching_keywords'] = matching_keywords
            article['matching_anti_keywords'] = matching_anti_keywords
            articles.append(article)

        # print the first 10 article titles
        if i < 10:
            print('Title:', title)

# convert the list of articles into a DataFrame
df = pd.DataFrame(articles)
# Out:
# Title: calculation of prompt diphoton production cross sections at tevatron and
#   lhc energies
# Title: sparsity-certifying graph decompositions
# Title: the evolution of the earth-moon system based on the dark matter field
#   fluid model
# Title: a determinant of stirling cycle numbers counts unlabeled acyclic
#   single-source automata
# Title: from dyadic $\lambda_{\alpha}$ to $\lambda_{\alpha}$
# Title: bosonic characters of atomic cooper pairs across resonance
# Title: polymer quantum mechanics and its continuum limit
# Title: numerical solution of shock and ramp compression for general material
#   properties
# Title: the spitzer c2d survey of large, nearby, insterstellar clouds. ix. the
#   serpens yso population as observed with irac and mips
# Title: partial cubes: structures, characterizations, and constructions

# %%
df
# Out:
#                     id                 submitter  \
# 0            1301.4564        Rafael Najmanovich
# 1            1406.6200           Thijs van Ommen
# 2           1503.05526             Fabrice Rossi
# 3           1606.05798                Guolong Su
# 4           1606.07163  William Souillard-Mandar
# ...                ...                       ...
# 1615        2308.00143                  Guy Amir
# 1616        2308.00184         Leopoldo Bertossi
# 1617        2308.00710           Igor Cherepanov
# 1618        2308.01475                Lili Zheng
# 1619  astro-ph/0409085          Santosh Vadawale
#
#                                                 authors  \
# 0                                    Rafael Najmanovich
# 1                                       Thijs van Ommen
# 2     Tsirizo Rabenoro (SAMM), J\'er\^ome Lacaille, ...
# 3     Guolong Su, Dennis Wei, Kush R. Varshney, Dmit...
# 4     William Souillard-Mandar, Randall Davis, Cynth...
# ...                                                 ...
# 1615  Shahaf Bassan, Guy Amir, Davide Corsi, Idan Re...
# 1616                                  Leopoldo Bertossi
# 1617  Igor Cherepanov, David Sessler, Alex Ulmer, He...
# 1618           Genevera I. Allen, Luqin Gan, Lili Zheng
# 1619  S. V. Vadawale, J. Hong, J. Grindlay, P. Willi...
#
#                                                   title  \
# 0     Protein flexibility upon ligand binding: Docki...
# 1     Combining predictions from linear models when ...
# 2     Interpretable Aircraft Engine Diagnostic via E...
# 3     Interpretable Two-level Boolean Rule Learning ...
# 4     Interpretable Machine Learning Models for the ...
# ...                                                 ...
# 1615  Formally Explaining Neural Networks within Rea...
# 1616  Attribution-Scores in Data Management and Expl...
# 1617  Towards the Visualization of Aggregated Class ...
# 1618  Interpretable Machine Learning for Discovery: ...
# 1619  Multipixel characterization of imaging CZT det...
#
#                                                comments  \
# 0     Thesis for the degree Doctor of Philosophy sub...
# 1     12 pages, 2 figures. To appear in Proceedings ...
# 2     arXiv admin note: substantial text overlap wit...
# 3     presented at 2016 ICML Workshop on Human Inter...
# 4     Presented at 2016 ICML Workshop on Human Inter...
# ...                                                 ...
# 1615  To appear in Proc. 23rd Int. Conf. on Formal M...
# 1616  Paper associated to ADBIS23 tutorial. To appea...
# 1617                submitted to xaiworldconference2023
# 1618                                               None
# 1619  To appears in the SPIE 2004 proceedings (5540:...
#
#                                             journal-ref                doi  \
# 0                                                  None               None
# 1                                                  None               None
# 2     Transactions on Machine Learning and Data Mini...               None
# 3                                                  None               None
# 4                                                  None               None
# ...                                                 ...                ...
# 1615                                               None               None
# 1616                                               None               None
# 1617                                               None               None
# 1618                                               None               None
# 1619                                               None  10.1117/12.559748
#
#                 report-no                             categories  \
# 0                    None                               q-bio.BM
# 1                    None                  stat.ME cs.LG stat.ML
# 2                    None  stat.ML cs.LG math.ST stat.AP stat.TH
# 3     WHI 2016 submission                          stat.ML cs.LG
# 4                    None                          stat.ML cs.LG
# ...                   ...                                    ...
# 1615                 None                      cs.AI cs.LG cs.LO
# 1616                 None                      cs.DB cs.AI cs.LG
# 1617                 None                      cs.LG cs.AI cs.HC
# 1618                 None                  stat.ML cs.LG stat.ME
# 1619                 None                               astro-ph
#
#                                                 license  \
# 0     http://arxiv.org/licenses/nonexclusive-distrib...
# 1     http://arxiv.org/licenses/nonexclusive-distrib...
# 2     http://arxiv.org/licenses/nonexclusive-distrib...
# 3     http://arxiv.org/licenses/nonexclusive-distrib...
# 4     http://arxiv.org/licenses/nonexclusive-distrib...
# ...                                                 ...
# 1615  http://arxiv.org/licenses/nonexclusive-distrib...
# 1616  http://arxiv.org/licenses/nonexclusive-distrib...
# 1617  http://creativecommons.org/licenses/by-nc-nd/4.0/
# 1618        http://creativecommons.org/licenses/by/4.0/
# 1619                                               None
#
#                                                abstract  \
# 0       Side chain flexibility is an important facto...
# 1       Methods for combining predictions from diffe...
# 2       Detecting early signs of failures (anomalies...
# 3       As a contribution to interpretable machine l...
# 4       The Clock Drawing Test (CDT) is a rapid, ine...
# ...                                                 ...
# 1615    Deep neural networks (DNNs) are increasingly...
# 1616    We describe recent research on the use of ac...
# 1617    Deep learning (DL) models achieve remarkable...
# 1618    New technologies have led to vast troves of ...
# 1619    We report our in-depth study of Cd-Zn-Te (CZ...
#
#                                                versions update_date  \
# 0     [{'version': 'v1', 'created': 'Sat, 19 Jan 201...  2013-01-22
# 1     [{'version': 'v1', 'created': 'Tue, 24 Jun 201...  2014-06-25
# 2     [{'version': 'v1', 'created': 'Wed, 18 Mar 201...  2015-03-19
# 3     [{'version': 'v1', 'created': 'Sat, 18 Jun 201...  2016-06-21
# 4     [{'version': 'v1', 'created': 'Thu, 23 Jun 201...  2016-06-24
# ...                                                 ...         ...
# 1615  [{'version': 'v1', 'created': 'Mon, 31 Jul 202...  2023-08-02
# 1616  [{'version': 'v1', 'created': 'Mon, 31 Jul 202...  2023-08-02
# 1617  [{'version': 'v1', 'created': 'Sat, 29 Jul 202...  2023-08-03
# 1618  [{'version': 'v1', 'created': 'Wed, 2 Aug 2023...  2023-08-04
# 1619  [{'version': 'v1', 'created': 'Fri, 3 Sep 2004...  2009-11-10
#
#                                          authors_parsed  \
# 0                             [[Najmanovich, Rafael, ]]
# 1                                [[van Ommen, Thijs, ]]
# 2     [[Rabenoro, Tsirizo, , SAMM], [Lacaille, Jérôm...
# 3     [[Su, Guolong, ], [Wei, Dennis, ], [Varshney, ...
# 4     [[Souillard-Mandar, William, ], [Davis, Randal...
# ...                                                 ...
# 1615  [[Bassan, Shahaf, ], [Amir, Guy, ], [Corsi, Da...
# 1616                           [[Bertossi, Leopoldo, ]]
# 1617  [[Cherepanov, Igor, ], [Sessler, David, ], [Ul...
# 1618  [[Allen, Genevera I., ], [Gan, Luqin, ], [Zhen...
# 1619  [[Vadawale, S. V., ], [Hong, J., ], [Grindlay,...
#
#                      matching_keywords matching_anti_keywords
# 0                                [xai]                     []
# 1                                [xai]                     []
# 2                   [interpretable ai]                     []
# 3     [interpretable machine learning]                     []
# 4     [interpretable machine learning]                     []
# ...                                ...                    ...
# 1615             [explainable ai, xai]                     []
# 1616    [explainable machine learning]                     []
# 1617                             [xai]                     []
# 1618  [interpretable machine learning]                     []
# 1619                             [xai]                     []
#
# [1620 rows x 16 columns]
